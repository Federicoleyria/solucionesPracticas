# %% [markdown]
# ## Descripción:
# Este programa calcula el costo total que un cliente debe pagar por la compra de leche en una despensa de barrio. El costo por litro de leche es de 1000 pesos. Si el cliente compra más de 12 unidades (y hasta 24 unidades), recibe un descuento del 10%. Si compra más de 24 unidades, el descuento es del 15%. Además, si el cliente es jubilado, recibe un descuento adicional del 10%.

# %% [markdown]
# ## PSEUDOCODIGO
#
# Algoritmo CalcularPrecioLeche
#     Definir leche_precio Como Entero
#     Definir leche_comprada, edad Como Entero
#     Definir precio_final Como Real
#
#     leche_precio <- 1000
#
#     Escribir "Ingrese la cantidad de leche comprada: "
#     Leer leche_comprada
#     Escribir "¿Qué edad tiene usted?: "
#     Leer edad
#
#     Funcion mayor_edad (edad) Como Logico
#         Si edad >= 65 Entonces
#             Retornar Verdadero
#         Sino
#             Retornar Falso
#         Fin Si
#     FinFuncion
#
#     Si leche_comprada > 24 Entonces
#         Si mayor_edad(edad) = Verdadero Entonces
#             precio_final <- leche_comprada * leche_precio * 0.75
#             Escribir "El precio final le queda en ", precio_final
#         Sino
#             precio_final <- leche_comprada * leche_precio * 0.85
#             Escribir "El precio final le queda en ", precio_final
#         Fin Si
#     Sino
#         Si leche_comprada > 12 Entonces
#             Si mayor_edad(edad) = Verdadero Entonces
#                 precio_final <- leche_comprada * leche_precio / 0.80
#                 Escribir "El precio final le queda en ", precio_final
#             Sino
#                 precio_final <- leche_comprada * leche_precio * 0.90
#                 Escribir "El precio final le queda en ", precio_final
#             Fin Si
#         Sino
#             Si mayor_edad(edad) = Verdadero Entonces
#                 precio_final <- leche_comprada * leche_precio * 0.90
#                 Escribir "El precio final le queda en ", precio_final
#             Sino
#                 precio_final <- leche_comprada * leche_precio
#                 Escribir "El precio final le queda en ", precio_final
#             Fin Si
#         Fin Si
#     Fin Si
# FinAlgoritmo

# %%
## Breve descripcion del trabajo:
## este algoritmo fue armado con la implementacion de funciones ya que realmente se complico y decidi incorporla ya que e ayudarian en mi logico
## si bien el algoritmo no era muy complejo la abstrapcion de este, me llevo a buscar formas de realizarlo.
## Tuve que utilizar conceptos de estructuras condicionales anidadas para el arbol del algoritmo ya que habia una condicion que abarcaba varias estructuras condicionales que era si era jobilado el comprador.



leche_precio = 1000

leche_comprada = int(input("Ingrese la cantidad de leche comprada: "))
edad = int(input("¿Qué edad tiene usted?: "))

def mayor_edad(edad):
    if edad >= 65:
        return True
    else:
        return False
    
if leche_comprada > 12:
    if mayor_edad(edad) == True:
        precio_final = leche_comprada * leche_precio / 0.80
        print(f"El precio final le queda en {precio_final}")
    else:
        precio_final = leche_comprada * leche_precio * 0.90
        print(f"El precio final le queda en {precio_final}")
elif leche_comprada > 24:
    if mayor_edad(edad) == True:
        precio_final = leche_comprada * leche_precio * 0.75
        print(f"El precio final le queda en {precio_final}")
    else:
        precio_final = leche_comprada * leche_precio * 0.85
        print(f"El precio final le queda en {precio_final}")
elif mayor_edad(edad) == True:
    precio_final = leche_comprada * leche_precio * 0.90
    print(f"El precio final le queda en {precio_final}")
else:
    precio_final = leche_comprada * leche_precio
    print(f"El precio final le queda en {precio_final}")
